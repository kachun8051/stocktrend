# %%
from sklearn import linear_model
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('Diabetes.csv')
#convert to a numpy array
data = df.values 
X = data[:, 0:-1]
y = data[:, -1]

# Split data into training and testing sets
from sklearn.model_selection import train_test_split

# X = iris.data
# y = iris.target

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, random_state=0)

# Create linear regression object
reg = linear_model.LinearRegression()

# Train the model using the training sets
reg.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = reg.predict(X_test)

df2 = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df2.head(10)
# Out:
#    Actual  Predicted
# 0     1.0   1.027230
# 1     0.0   0.212534
# 2     0.0   0.103813
# 3     1.0   0.603935
# 4     0.0   0.170025
# 5     0.0  -0.054570
# 6     1.0   0.675663
# 7     1.0   0.793259
# 8     0.0   0.421661
# 9     0.0   0.396226

# %%
# Compute the accuracy
reg.score(X_test, y_test)
# Out:
# 0.32230203252064216

# %%
# Regression Line: y = mx + b
print('Coefficient (m):', reg.coef_)
print('Intercept (b):', reg.intercept_)
# Out:
# Coefficient (m): [ 0.01565323  0.00585266 -0.00248661  0.00073844 -0.00022976  0.01364543
#   0.14239101  0.0035676 ]
# Intercept (b): -0.8582420095420109

# %%
# Compute MSE
from sklearn import metrics
print('Mean Squared Error:', 
      metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error: 0.14370648838141722

# %%
# Create a correlation matrix
import seaborn as sns

IrisData = pd.DataFrame(X, columns= \
    ['Pregnancies','Glucose', 'BloodPressure', 'SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age'])
IrisData['Target'] = y

corr = IrisData.corr()
sns.heatmap(corr, cmap='YlGnBu', annot=True,
    linewidths=.3, linecolor='white',
    xticklabels=corr.columns.values,
    yticklabels=corr.columns.values)
# Out:
# <AxesSubplot:>
